# %% [markdown]
# <a href="https://colab.research.google.com/github/NikhilSengar/Capstone-1-The-Global-Terrorism-Database-Nikhil-Sengar/blob/main/EDA_Global_Terrorism_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - **Global Terrorism Dataset**
#
# ---

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name** - Nikhil Sengar

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# For the project, I have work on a study of terrorism and responses to terrorism(STERT) global terrorism data set by the University of Maryland , college park in the United States. It contains information on approximately more than 180,000 terrorist events, and a total of 135 attributes for each event, including exact date, location, group, weapon, casualty, summary of attack, motive,etc. GTD is an open source database including information on terrorist events around the world from 1970 to 2017. Terror attacks are important event to analyze, it is very important to evaluate how deadly terrorist attack can be when a particular region is targeted by a certain terror group.
#
# I will do this project in five parts,
#
# Part 1
#
# The first part of project deals with exploratory data analysis (EDA) to familiarize with the dataset in order to perform a preprocessing and data cleaning. In the processing and cleaning I need to find about Duplicate values and  Missing values/ Null values.
#
#
# Part 2
#
# The second part of the project is to understand the variable . In this I understand the variable description which is mention in the report and check unique values for each variables.
#
#
# Part 3
#
# In third part I will work on data wrangling , refers to the process of cleaning, transforming, organizing raw data into a structured and usable format. In this process I work on data to combine some informations such as in which country How many number of casualties occur, Number of people killed by terrorist organizations , Top 10 terrorist organizations in a country, Number of attack by every terrorist organizations in each country, Different types of successful attacks, Number of people killed and wounded every year by terrorist organizations.
#
#
# Part 4
#
# The next part is deals with the exploratory data analysis in that with all the geographical and time series information available, the best way to understand this data was by using visualization. I have used many python libraries like numpy, pandas, matplotlib, seaborn.
#
# In this data visualization process I need to understand the relationship between variables and find out some interesting data with the help of data visualization.
#
# With the help of data visualization, I will have to show some meaningfull charts and then explain everything about the chart. In this process I will find out terrorist attack per year, Total number of attack every year by region, Type of attack, Top 10 countries which are most affected by terrorist groups, Top 10 terrorist organizations with highest number of attacks.
#
# I will also visualize the terrorist attack in India and the casualties occur due to that attacks, The number of terrorist attacks in each city of India , I will compare country with the region in context of terrorist attack over the time.
#
# Part 5
#
# The last part of the report is to provide Solution to Reducing Terrorism and I have to provide some solution based upon the work i have done in the whole report. Eg. Address Root Causes, Counter Radicalization and Extremist Propaganda.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/NikhilSengar/Capstone-1-The-Global-Terrorism-Database-Nikhil-Sengar.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **The Global Terrorism Database**
#
# The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks. The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.
#
# Terrorism is a complex political and social phenomenon. Terrorist attacks have a significant threat to the safety and security of the international community and have become one of the greatest obstacles to the sustainable development of global social security. Terrorist attacks pose a great threat to global security, and their analysis and prediction are imperative.
#
# In this project we will analyse global terrorism database, do exploratory data analysis to understand more about the dataset and its topic, Visualize analysis, Analyze the data more deeply and extract insights.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# In this project I will analyse global terrorism database to understand more about the dataset and its topic, Visualize analysis, Analyze the data more deeply and extract insights to reduce the terrorist attacks.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams
import seaborn as sns
import time

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/EDA/Global Terrorism Data.csv'
path = pd.read_csv(file_path,encoding = "ISO-8859-1")
# Out:
# <ipython-input-3-77c3ecb8d31d>:2: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   path = pd.read_csv(file_path,encoding = "ISO-8859-1")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df = path[['eventid', 'iyear', 'imonth', 'iday', 'resolution', 'country_txt', 'region_txt', 'provstate',
           'city', 'crit1', 'crit2', 'crit3', 'multiple', 'success', 'suicide','attacktype1_txt',
           'targtype1_txt', 'targsubtype1_txt','corp1', 'target1', 'natlty1_txt', 'gname', 'guncertain1',
           'motive', 'claimed', 'weaptype1_txt', 'nkill',  'nwound', 'nwoundus', 'nwoundte',
           'propextent_txt', 'propvalue', 'ishostkid', 'nreleased']]

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday resolution         country_txt  \
# 0  197000000001   1970       7     2        NaN  Dominican Republic
# 1  197000000002   1970       0     0        NaN              Mexico
# 2  197001000001   1970       1     0        NaN         Philippines
# 3  197001000002   1970       1     0        NaN              Greece
# 4  197001000003   1970       1     0        NaN               Japan
#
#                     region_txt provstate           city  crit1  ...  claimed  \
# 0  Central America & Caribbean       NaN  Santo Domingo      1  ...      NaN
# 1                North America   Federal    Mexico city      1  ...      NaN
# 2               Southeast Asia    Tarlac        Unknown      1  ...      NaN
# 3               Western Europe    Attica         Athens      1  ...      NaN
# 4                    East Asia   Fukouka        Fukouka      1  ...      NaN
#
#    weaptype1_txt  nkill  nwound  nwoundus nwoundte propextent_txt propvalue  \
# ...

# %%
df.tail()
# Out:
#              eventid  iyear  imonth  iday resolution  country_txt  \
# 181686  201712310022   2017      12    31        NaN      Somalia
# 181687  201712310029   2017      12    31        NaN        Syria
# 181688  201712310030   2017      12    31        NaN  Philippines
# 181689  201712310031   2017      12    31        NaN        India
# 181690  201712310032   2017      12    31        NaN  Philippines
#
#                         region_txt        provstate           city  crit1  \
# 181686          Sub-Saharan Africa  Middle Shebelle  Ceelka Geelow      1
# 181687  Middle East & North Africa         Lattakia         Jableh      1
# 181688              Southeast Asia      Maguindanao       Kubentog      1
# 181689                  South Asia          Manipur         Imphal      1
# 181690              Southeast Asia      Maguindanao  Cotabato City      1
#
#         ...  claimed  weaptype1_txt  nkill  nwound  nwoundus nwoundte  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (181691, 34)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 34 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   eventid           181691 non-null  int64
#  1   iyear             181691 non-null  int64
#  2   imonth            181691 non-null  int64
#  3   iday              181691 non-null  int64
#  4   resolution        2220 non-null    object
#  5   country_txt       181691 non-null  object
#  6   region_txt        181691 non-null  object
#  7   provstate         181270 non-null  object
#  8   city              181257 non-null  object
#  9   crit1             181691 non-null  int64
#  10  crit2             181691 non-null  int64
#  11  crit3             181691 non-null  int64
#  12  multiple          181690 non-null  float64
#  13  success           181691 non-null  int64
#  14  suicide           181691 non-null  int64
#  15  attacktype1_txt   181691 non-null  object
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isnull().sum())
# Out:
# eventid                  0
# iyear                    0
# imonth                   0
# iday                     0
# resolution          179471
# country_txt              0
# region_txt               0
# provstate              421
# city                   434
# crit1                    0
# crit2                    0
# crit3                    0
# multiple                 1
# success                  0
# suicide                  0
# attacktype1_txt          0
# targtype1_txt            0
# targsubtype1_txt     10373
# corp1                42550
# target1                636
# natlty1_txt           1559
# gname                    0
# guncertain1            380
# motive              131130
# claimed              66120
# weaptype1_txt            0
# nkill                10313
# nwound               16311
# nwoundus             64702
# nwoundte             69143
# propextent_txt      117626
# propvalue           142702
# ishostkid              178
# nreleased           171291
# ...

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# In this available dataset, mentioned information about group responsible for an attack, Attack Type, Weapons used, Description of attack, Location, etc. From this data we can find out Country with the highest number of Terrorist Attacks, Regions with the highest number of Terrorist Attacks, & Maximum number of people were killed by a single terrorist attack. In this project we will use step-by-step approach to problem including visualization with the help of certain libraries
#
# The above dataset has 181691 rows and 135 columns. There are no mising values and duplicate values in the dataset.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'resolution', 'country_txt',
#        'region_txt', 'provstate', 'city', 'crit1', 'crit2', 'crit3',
#        'multiple', 'success', 'suicide', 'attacktype1_txt', 'targtype1_txt',
#        'targsubtype1_txt', 'corp1', 'target1', 'natlty1_txt', 'gname',
#        'guncertain1', 'motive', 'claimed', 'weaptype1_txt', 'nkill', 'nwound',
#        'nwoundus', 'nwoundte', 'propextent_txt', 'propvalue', 'ishostkid',
#        'nreleased'],
#       dtype='object')

# %%
# Dataset Describe
df.describe(include='all')
# Out:
#              eventid          iyear         imonth           iday resolution  \
# count   1.816910e+05  181691.000000  181691.000000  181691.000000       2220
# unique           NaN            NaN            NaN            NaN       1859
# top              NaN            NaN            NaN            NaN   8/4/1998
# freq             NaN            NaN            NaN            NaN         18
# mean    2.002705e+11    2002.638997       6.467277      15.505644        NaN
# std     1.325957e+09      13.259430       3.388303       8.814045        NaN
# min     1.970000e+11    1970.000000       0.000000       0.000000        NaN
# 25%     1.991021e+11    1991.000000       4.000000       8.000000        NaN
# 50%     2.009022e+11    2009.000000       6.000000      15.000000        NaN
# 75%     2.014081e+11    2014.000000       9.000000      23.000000        NaN
# max     2.017123e+11    2017.000000      12.000000      31.000000        NaN
#
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1. **GTD ID and Date** - Eventid- GTD ID ,Year, Month, Resolution-Date of Extended Incident Resolution
#
# 2. **Incident Information** - Inclusion Criteria(crit1, crit2, crit3),Part of Multiple Incident(multiple)
# 3. **Incident Location** - Country, Region, Province / State(provstate), City
# 4. **Attack Information** - Attack Type(Attacktype) - Assassination, Hijacking, Kidnapping,Barricade Incident, Bombing/Explosion, Armed Assault, Unarmed Assault, Facility/Infrastructure Attack, Unknown.
# Successful Attack(success).
# Suicide Attack(suicide)
# 5. **Weapon Information** - Weapon Type(Weaptype)
# 6. **Target/Victim Information** - Target/Victim Type(Targtype), Nationality of Target/Victim(Natlty1).Name of Entity(corp1)
# 7. **Perpetrator Information** - Perpetrator Group Name(gname), First Perpetrator Group Suspected(guncertain1), Claim of Responsibility(claimed), Motive(motive).
#
# 8. **Casualties and Consequences** - Total Number of Fatalities(nkill), Total Number of Injured(nwound).
# Extent of Property Damage(propextent_txt).
# Value of Property Damage (in USD) (propvalue).
# Hostages or Kidnapping Victims(ishostkid)
# Number Released/Escaped/Rescued (nreleased)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns.tolist():
  print("No. of unique values in ",i,"is",df[i].nunique(),".")
# Out:
# No. of unique values in  eventid is 181691 .
# No. of unique values in  iyear is 47 .
# No. of unique values in  imonth is 13 .
# No. of unique values in  iday is 32 .
# No. of unique values in  resolution is 1859 .
# No. of unique values in  country_txt is 205 .
# No. of unique values in  region_txt is 12 .
# No. of unique values in  provstate is 2855 .
# No. of unique values in  city is 36674 .
# No. of unique values in  crit1 is 2 .
# No. of unique values in  crit2 is 2 .
# No. of unique values in  crit3 is 2 .
# No. of unique values in  multiple is 2 .
# No. of unique values in  success is 2 .
# No. of unique values in  suicide is 2 .
# No. of unique values in  attacktype1_txt is 9 .
# No. of unique values in  targtype1_txt is 22 .
# No. of unique values in  targsubtype1_txt is 112 .
# No. of unique values in  corp1 is 33238 .
# No. of unique values in  target1 is 86006 .
# No. of unique values in  natlty1_txt is 215 .
# No. of unique values in  gname is 3537 .
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Creating a DataFrame of no. of kills in each Country.
pd.DataFrame(df.groupby('country_txt')['nkill'].count()).reset_index()
# Out:
#      country_txt  nkill
# 0    Afghanistan  12362
# 1        Albania     76
# 2        Algeria   2719
# 3        Andorra      0
# 4         Angola    482
# ..           ...    ...
# 200        Yemen   3083
# 201   Yugoslavia    195
# 202        Zaire     50
# 203       Zambia     60
# 204     Zimbabwe     96
#
# [205 rows x 2 columns]

# %%
# Getting a value of no. of kills by terrorist organisations.
df.groupby('gname')['nkill'].sum().sort_values(ascending=False)[:10]
# Out:
# gname
# Unknown                                             112367.0
# Islamic State of Iraq and the Levant (ISIL)          38923.0
# Taliban                                              29410.0
# Boko Haram                                           20328.0
# Shining Path (SL)                                    11601.0
# Liberation Tigers of Tamil Eelam (LTTE)              10989.0
# Al-Shabaab                                            9330.0
# Farabundo Marti National Liberation Front (FMLN)      8065.0
# Nicaraguan Democratic Force (FDN)                     6662.0
# Tehrik-i-Taliban Pakistan (TTP)                       6042.0
# Name: nkill, dtype: float64

# %%
# Creating DataFrame of no. of attack by every terrorist organisations in each country.
pd.DataFrame(df.groupby('country_txt')['gname'].value_counts().reset_index(name="Count"))
# Out:
#       country_txt                                  gname  Count
# 0     Afghanistan                                Taliban   7423
# 1     Afghanistan                                Unknown   4806
# 2     Afghanistan  Khorasan Chapter of the Islamic State    242
# 3     Afghanistan                        Haqqani Network     84
# 4     Afghanistan                          Hizb-I-Islami     42
# ...           ...                                    ...    ...
# 5358     Zimbabwe                                 Gunmen      1
# 5359     Zimbabwe    Liberation War Veterans Association      1
# 5360     Zimbabwe     National Youth Service of Zimbabwe      1
# 5361     Zimbabwe                  Right-wing extremists      1
# 5362     Zimbabwe               South African guerrillas      1
#
# [5363 rows x 3 columns]

# %%
# Top 10 Terriorist Organisations attack in Pakistan
country_df = df.explode('country_txt')
pd.DataFrame(country_df[country_df['country_txt'].isin(['Pakistan'])].explode('nkill')['gname'].value_counts().reset_index(name="Attack Information"))[:10]
# Out:
#                                    index  Attack Information
# 0                                Unknown               10891
# 1        Tehrik-i-Taliban Pakistan (TTP)                1335
# 2           Baloch Republican Army (BRA)                 312
# 3          Baloch Liberation Front (BLF)                 185
# 4           Baloch Liberation Army (BLA)                 181
# 5          Muttahida Qami Movement (MQM)                 174
# 6                      Lashkar-e-Jhangvi                 135
# 7             Lashkar-e-Islam (Pakistan)                 124
# 8  Khorasan Chapter of the Islamic State                  96
# 9               United Baloch Army (UBA)                  89

# %%
# Different types of successful attacks
pd.DataFrame(df.groupby('attacktype1_txt')['success'].count()).reset_index()
# Out:
#                        attacktype1_txt  success
# 0                        Armed Assault    42669
# 1                        Assassination    19312
# 2                    Bombing/Explosion    88255
# 3       Facility/Infrastructure Attack    10356
# 4                            Hijacking      659
# 5  Hostage Taking (Barricade Incident)      991
# 6          Hostage Taking (Kidnapping)    11158
# 7                      Unarmed Assault     1015
# 8                              Unknown     7276

# %%
# Finding out different types of attacks in countries.
pd.DataFrame(df.groupby('country_txt')['attacktype1_txt'].value_counts().reset_index(name="Count"))
# Out:
#       country_txt                      attacktype1_txt  Count
# 0     Afghanistan                    Bombing/Explosion   6245
# 1     Afghanistan                        Armed Assault   2877
# 2     Afghanistan                              Unknown   1173
# 3     Afghanistan          Hostage Taking (Kidnapping)   1011
# 4     Afghanistan                        Assassination    954
# ...           ...                                  ...    ...
# 1274     Zimbabwe       Facility/Infrastructure Attack      6
# 1275     Zimbabwe                              Unknown      5
# 1276     Zimbabwe          Hostage Taking (Kidnapping)      4
# 1277     Zimbabwe  Hostage Taking (Barricade Incident)      2
# 1278     Zimbabwe                      Unarmed Assault      2
#
# [1279 rows x 3 columns]

# %%
# No. of people killed and wounded every year from 1970 to 2017 by terrorist organisations.
df.groupby('iyear').agg({"gname": "sum", "nkill": "count", "nwound": "count"})
# Out:
#                                                    gname  nkill  nwound
# iyear
# 1970   MANO-D23rd of September Communist LeagueUnknow...    609     599
# 1971   White extremistsUnknownStudent RadicalsLeft-Wi...    407     326
# 1972   UnknownUnknownPopular Front for the Liberation...    524     241
# 1973   National Liberation Army of Colombia (ELN)Ulst...    424     244
# 1974   Red BrigadesUnknownUnknownUnknownIrish Republi...    523     352
# 1975   UnknownFirst of October Antifascist Resistance...    587     400
# 1976   Armenian Secret Army for the Liberation of Arm...    814     620
# 1977   Tribal BattlefrontTribal BattlefrontTribal Bat...   1189    1104
# 1978   UnknownUnknownProletarian PatrolsProletarian P...   1373    1331
# 1979   UnknownPopular Liberation Army (EPL)New People...   2257    2200
# 1980   PalestiniansIrish Republican Army (IRA)Irish R...   2211    2150
# 1981   Irish Republican Army (IRA)UnknownUnified Kurd...   1928    1883
# ...

# %%
# Getting Unique Countries/territories/regions
print(df['country_txt'].unique())
print(" ")
# Getting Unique Countries Count
print("Unique Country Count is ",df['country_txt'].nunique(),".")
# Out:
# ['Dominican Republic' 'Mexico' 'Philippines' 'Greece' 'Japan'
#  'United States' 'Uruguay' 'Italy' 'East Germany (GDR)' 'Ethiopia'
#  'Guatemala' 'Venezuela' 'West Germany (FRG)' 'Switzerland' 'Jordan'
#  'Spain' 'Brazil' 'Egypt' 'Argentina' 'Lebanon' 'Ireland' 'Turkey'
#  'Paraguay' 'Iran' 'United Kingdom' 'Colombia' 'Bolivia' 'Nicaragua'
#  'Netherlands' 'Belgium' 'Canada' 'Australia' 'Pakistan' 'Zambia' 'Sweden'
#  'Costa Rica' 'South Yemen' 'Cambodia' 'Israel' 'Poland' 'Taiwan' 'Panama'
#  'Kuwait' 'West Bank and Gaza Strip' 'Austria' 'Czechoslovakia' 'India'
#  'France' 'South Vietnam' 'Brunei' 'Zaire'
#  "People's Republic of the Congo" 'Portugal' 'Algeria' 'El Salvador'
#  'Thailand' 'Haiti' 'Sudan' 'Morocco' 'Cyprus' 'Myanmar' 'Afghanistan'
#  'Peru' 'Chile' 'Honduras' 'Yugoslavia' 'Ecuador' 'New Zealand' 'Malaysia'
#  'Singapore' 'Botswana' 'Jamaica' 'Chad' 'North Yemen' 'Andorra' 'Syria'
#  'South Korea' 'United Arab Emirates' 'South Africa' 'Kenya' 'Iraq'
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I have done all the manipulations by using groupby, count, Agg., explode, Reset, and Unique method. From all the above manipulations, We can find out the number of people killed in specific country, which group is responsible for that attack, which type of attack that was, and how many number of people killed and wounded by which group, how many successfull attack has done, top most terrorist organisations and different type of attacks occurred in any country.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
#Visualizing the Terrorist attack per year
#attack_per_year = df['iyear'].value_counts()
ax = sns.countplot(x='iyear',data=df)
ax.set_title("Terrorist attack per year", fontsize = 20)
plt.xticks(rotation = 90)
ax.set_xlabel("Year", fontsize = 15)
ax.set_ylabel("Count", fontsize = 15)
plt.rcParams['figure.figsize'] = (15, 5)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart shows Frequency Comparison of values. A bar chart allows for a straightforward comparison of the frequency or count of a specific variable.
#
# I have use the bar chart to compare the number of terrorist attack happened every year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart I got to know that there are consistent fluctuations in attack frequency till the year 2011.But after 2011 there is sudden change in pattern of bar but after 2011, increased in terrorist activities and 2014-15 are the peak years, in that period highest number of terrorist attacks occurred.
#
# We can say that, long-term pattern has increase in terrorism over the years.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Visualizing terrorist attacks on a year-to-year basis can provide businesses with a clearer understanding of the frequency, patterns, and locations of such attacks. This increased awareness enables government/security department/forces to assess the potential risks and threats they may face, both locally and globally.
#
# Continuous visualization of terrorist attacks can create a climate of fear and panic among businesses and individuals. This heightened sense of insecurity might discourage investment, tourism, and economic activities in regions or countries perceived as high-risk, leading to a negative impact on business growth.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
#Visualizing the Deaths in South Asia
region = df[df['region_txt']=='South Asia']
yearly_death_count = pd.DataFrame(region.groupby(['iyear'])['nkill'].sum())

plt.plot(yearly_death_count)
plt.title('Deaths in South Asia',fontsize = 20)
plt.xlabel('Year',fontsize = 15)
plt.ylabel('No. of death',fontsize = 15)
plt.rcParams['figure.figsize'] = (15, 5)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line plots are effective in visualizing how certain variables evolve over time.
#
# I have use the line plot to show the variation in number of casualties in south asia over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In above chart, the overall pattern of death is increasing over the times but after 2011 there is sudden jump in number of deaths.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Visualizing the deaths caused by terrorist attacks in South Asia provides businesses/govt./army with a clearer understanding of the severity and impact of terrorism in the region.
#
# This could creat negative perception of South Asia due to that tourism and other economic activities will reduced and this could lead to negative impact on economic growth and development.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
#Visualizing Total no. of attack every year by region
total_no_of_attack = df.groupby(['iyear','region_txt'])['iyear'].count().unstack()

total_no_of_attack.plot()

plt.title('Total no. of attack every year by region',fontsize = 20)
plt.xlabel('Year',fontsize = 15)
plt.ylabel('No. of attack',fontsize = 15)
plt.rcParams['figure.figsize'] = (15, 5)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Multiple line plots allow for a direct visual comparison between different variables.
#
# I have use this Multiple line plot to plot the number of terrorist attacks every year in different regions on seperate lines within the same plot.This enables a quick comparison of how terrorism trends differ across these regions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart I got to know that the Middle East & North Africa is highly prone to terrorist activities and it increases over the period of time specially after the year 2011 there is sudden jump in terrorist activities in this area. After Middle East & North Africa, South Asia is most affected region of terrorist attacks.
#
# Australia and Oceania is the least affected region of terrorist activities.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By analyzing attack patterns and trends, businesses can assess the level of risk associated with specific regions. This information allows businesses to develop targeted risk mitigation strategies, such as implementing enhanced security measures or adjusting their business operations to minimize exposure to high-risk areas.
#
# Because of focusing and emphasizing security risks on specific region it can potentially increase the geopolitical tensions and conflicts.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
#Visualizing the Type of attack
type_of_attack = df["attacktype1_txt"].value_counts()
type_of_attack.plot(kind='pie',autopct='%1.1f%%')
plt.title('Type of attack',fontsize=20)
plt.rcParams['figure.figsize'] = (10, 10)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts are effective in visually representing the proportional distribution of a categorical variable.
#
# I have use this pie chart to show the distribution of terrorist attacks by type of attack. Each part of pie represents category and the size of each slice corresponds to percentage of type of attack.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In above chart there are the distribution of attack types such as bombings/explosion, armed assaults, assassinations, hijackings,infrastructure attack, or others.
#
# The most number of time terrorist attack through Bombing/Explosion(48.6%), after that Armed assault(23.5%), Assassination(10.6%), Kidnapping(6.1%), Infrastructure attack(5.7%), Unknown(4%), Unarmed assault(0.6%), Barricade incident(0.5%), Hijacking(0.4%).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By understanding the specific types of attacks prevalent in certain regions or industries, businesses can implement measures to safeguard their operations, assets, and personnel from those specific threats.It can enhanced security measures.
#
# Visualizations that highlight the types of attacks may inadvertently inspire or provide ideas to potential perpetrators.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
#Visualizing the Top 10 Countries: Most Attacks by Terrorist Groups
most_attacked_countries = sns.barplot(x=df['country_txt'].value_counts()[0:10].index, y=df['country_txt'].value_counts()[0:10])
most_attacked_countries.set_title("Top 10 Countries: Most Attacks by Terrorist Groups'", fontsize = 20)
most_attacked_countries.set_xlabel("Country", fontsize = 15)
most_attacked_countries.set_ylabel("Count", fontsize = 15)
plt.rcParams['figure.figsize'] = (15, 5)
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart shows Frequency Comparison of values. A bar chart allows for a comparison of the frequency or count of a specific variable.
#
# I have use the bar chart to compare the top 10 countries which has most number of terrorist attack.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In above chart, I found out about the top 10 countries where most number of terrorist attack occurred. In this chart Iraq is on the top with the highest number of terrorist attack occurred in that country after that Pakistan, Afghanistan are second and third highly affected country by Terrorist groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It provides valuable insights for businesses/companies to make informed decisions, allocate resources effectively, and enhance security measures.
#
# It can creat economic and investment deterrence in those regions.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
#Visualizing the number of terrorist attacks in India
attacks_on_india = df[(df['country_txt'] == 'India')]
attacks_per_year = attacks_on_india['iyear'].value_counts().sort_index()
attacks_per_year.plot(marker='o')
plt.title('Terrorist Attacks in India',fontsize = 20)
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Number of Attacks',fontsize = 15)
plt.rcParams['figure.figsize'] = (15, 5)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line plots are effective in visualizing how certain variables evolve over time.
#
# I have use the line plot to show the variation in number of terrorist attacks in India over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above chart I got to know that there is sudden spike in number of terrorist activities after 2007 after that attacks are contineously increased and the peak of the number of attack is year 2016.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This will help to Enhanced threat awareness, Risk mitigation and contingency planning, Strengthened security measures, Geographical expansion decisions, Collaboration and information sharing.
#
# Foreign direct investment, tourism, and trade may decline, leading to reduced business opportunities and economic growth.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
#Visualizing the number of deaths in India
country = df[df['country_txt']=='India']
yearly_death_in_india = pd.DataFrame(country.groupby(['iyear'])['nkill'].sum())
plt.plot(yearly_death_in_india)
plt.title('Deaths in India',fontsize = 20)
plt.xlabel('Year',fontsize = 15)
plt.ylabel('No. of death',fontsize = 15)
plt.rcParams['figure.figsize'] = (15, 5)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line plots are effective in visualizing how certain variables evolve over time.
#
# I have use the line plot to show the variation in number of casualties in India over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The number of deaths in India is very high during the period of 1985-92 and 1992 is peak of death in India this may be due to Bombay Bombings, Communal Tensions, Ethnic and Separatist Conflicts, Militant Groups and Extremist Organizations, Security and Intelligence Challenges.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
#Visualizing the number of terrorist attacks in cities of India
attacks_on_india = df[(df['country_txt'] == 'India')]
columns = ['iyear', 'city']
attacks_on_indian_city = attacks_on_india[columns]
city_counts = attacks_on_indian_city['city'].value_counts()
top_cities = city_counts.head(10)
top_cities.plot(kind='bar')
plt.title('Number of Terrorist Attacks in Cities of India',fontsize = 20)
plt.xlabel('City',fontsize = 15)
plt.ylabel('Number of Attacks',fontsize = 15)
plt.rcParams['figure.figsize'] = (15, 5)
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart shows Frequency Comparison of values. A bar chart allows for a comparison of the frequency or count of a specific variable.
#
# I have use the bar chart to compare the top 10 cities in India where most number of terrorist attack had occurred.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above chart, there mention that the Srinagar is highly impacted by terrorist activities this may be due to Kashmir Conflict, Ethnic and Separatist Movements.
#
# Imphal is also impacted of terrorist activities due to Ethnic and Insurgent Movements, Proximity to International Borders.
#
# Most of the cities mentioned in chart is either Strategic Significance or Proximity to International Borders this could be the reason of terror activities are high in that areas.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# After getting the information of attack, It can foster collaboration and cooperation between businesses and the government. The visualization provides a shared understanding of the security challenges faced by specific cities, enabling businesses and government agencies to work together in developing effective counterterrorism strategies.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
#evolution of terrorism in a specific country or region
country = 'India'
region = 'South Asia'
country_attacks = df[df['country_txt'] == country]
region_attacks = df[df['region_txt'] == region]
country_attacks_per_year = country_attacks['iyear'].value_counts().sort_index()
region_attacks_per_year = region_attacks['iyear'].value_counts().sort_index()
country_attacks_per_year.plot(label=country)
region_attacks_per_year.plot(label=region)
plt.title('Terrorist Attacks Over Time: Country vs Region', fontsize = 20)
plt.xlabel('Year', fontsize = 15)
plt.ylabel('Number of Attacks', fontsize = 15)
plt.legend()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Multiple line plots allow for a direct visual comparison between different variables.
#
# I have use the multiple line plot to compare the evolution of terrorism in a specific country or region. This enable me to compare the evolution of terrorism in India and South Asia.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The above chart shows the evolution of terrorism in India and the South asia(the region where India belongs).
#
# The above chart shows that as compare to the whole region of south asia India is less impacted by terrorist activities.
# In the other region of south asia where terrorist activities are high, there is sudden increase in number of attack after 2011 and other than that there is less growth in number of attack in India.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This comparison between India and the South Asia region allows businesses to identify countries within the region that offer government support, incentives, or special economic zones for business development. As we can see the terrorist attack in India is less in compare to the average of the region it could show the policy of Govt., Infrastructure development.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
#Top 10 Terrorist Organizations with Highest Number of Attacks
grouped_data = df.groupby('gname')['eventid'].count()
grouped_data = grouped_data.drop('Unknown')
top_10_organizations = grouped_data.nlargest(10).index
grouped_data = grouped_data[top_10_organizations]
sns.countplot(y='gname', data=df[df['gname'].isin(top_10_organizations)], order=top_10_organizations)
plt.title('Top 10 Terrorist Organizations with Highest Number of Attacks', fontsize=20)
plt.xlabel('Number of Terrorist Attacks', fontsize=15)
plt.ylabel('Terrorist Organization', fontsize=15)
# Out:
# Text(0, 0.5, 'Terrorist Organization')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Bar plot allows for easy comparison between different categories and provides a clear visual representation of the frequency of attacks.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart we can see the top 10 terrorist organizations responsible for the highest number of attacks.
#
# Taliban is the group who is responsible for highest number of terrorist attacks.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# **Solution to Reducing Terrorism**
# * Enhance Intelligence and Information Sharing.
# * Strengthen Border Security.
# * Address Root Causes.
# * Counter Radicalization and Extremist Propaganda.
# * Strengthen International Cooperation.
# * Promote Community Engagement and Empowerment.
# * Strengthen International Norms and Cooperation.
# * Promote Conflict Resolution and Peacebuilding.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In this project I have analyse the dataset and found out some intresting information. I have done a  Exploratory Data Analysis by using python libraries like numpy, pandas, matplotlib, seaborn that allow us to conclusion calculating and visualization.
#
# From the above analysis we conclude that
#
# * From the analysis we can see that on 2014 the number of terrorist activities were the highest in Whole world.
# * Middle East & North Africa region has highest number of attacks.
# * The most number of time terrorist attack through Bombing/Explosion(48.6%).
# * Iraq country has highest number of attacks.
# * In India there is sudden spike in number of terrorist activities after 2007 & the peak is year 2016.
# * Srinagar city in India has highest number of attacks.
# * Taliban is the group responsible for highest number of terrorist attacks.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
